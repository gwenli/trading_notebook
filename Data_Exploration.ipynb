# %%
# %matplotlib inline
import numpy as np
import json
import requests
import quandl
import matplotlib.pyplot as plt
import pandas
BASEURIIEX = "https://api.iextrading.com/1.0/stock/msft/chart/1y?"
BASEURIQDL = "https://www.quandl.com/api/v3/datasets/CHRIS/CME_RB1"
# GET request from iextrading
def iex_get_request( params ):
    request_uri = BASEURIIEX
    for each_key in params:
        request_uri = request_uri + each_key + "=" + params[each_key]
    print (request_uri)

iex_get_request ({"symbols":"fb"})

# # GET request from quandl
# def quandl_get_request( params ):
#     request_uri = BASEURIQDL
#     for each_key in params:
#         request_uri = request_uri + each_key + "=" + params[each_key]
#     print (request_uri)

# quandl_get_request ({"symbols":"fb"})
# mydata = quandl.get("EIA/PET_RWTC_D")
# print(mydata)

mydata = quandl.get("EIA/PET_RWTC_D", start_date="2012-12-31", end_date="2018-12-31", returns="dataframe")
# print(mydata)
# print(mydata.shape[0])
# print(mydata.Value)
mydata.plot()
# def plot_outcome( md ):
#     mdlength = md.shape[0]
#     for mdlength
# Out:
# https://api.iextrading.com/1.0/stock/msft/chart/1y?symbols=fb
